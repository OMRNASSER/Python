# %%
print("hello world!")
# Out:
# hello world!

# %%
x=int(5)
print(x)
#python 
# It is used for:
    # web development (server-side),
    # software development,
    # mathematics,
    # system scripting.
# What can Python do?
    # Python can be used on a server to create web applications.
    # Python can be used alongside software to create workflows.
    # Python can connect to database systems. It can also read and modify files.
    # Python can be used to handle big data and perform complex mathematics.
    # Python can be used for rapid prototyping, or for production-ready software development.
    

"""
indentation in python

    Python uses indentation to indicate a block of code.
"""   


if x >= 5 :
    print("yes")

#Casting
x = str(3)
print(x)
z = float(3) 
print(z)
y = 20 

print(type(x))
print(type(y))
print(type(z))


x = y = z = 25 
print(x) 
print(y) 
print(z)

#Unpack a collection
""""
If you have a collection of values in a list, tuple etc. 
Python allows you to extract the values into variables.
This is called unpacking
"""

fruits = ["apple" , "banana" , "cherry"]
x,y ,z=  fruits 
print(x) 
print(y) 
print(z)




print(x +" "+ y+" " +z+" ")
# Out:
# 5
# yes
# 3
# 3.0
# <class 'str'>
# <class 'int'>
# <class 'float'>
# 25
# 25
# 25
# apple
# banana
# cherry
# apple banana cherry

# %%
#global variables 
# keyword "global" : To change the value of a global variable inside a function

def myfunc():
    global g 
    g ="fantastic"
    y = g + " and Awesome!"
    print(y)
myfunc()
print(g)
if __name__ == '__main__':
    print("hello world")
    print(g)
# Out:
# fantastic and Awesome!
# fantastic
# hello world
# fantastic

# %%
#Data Types in Python

# Text Type:	str
# Numeric Types:	int, float, complex
# Sequence Types:	list, tuple, range
# Mapping Type:	dict
# Set Types:	set, frozenset
# Boolean Type:	bool
# Binary Types:	bytes, bytearray, memoryview
# None Type:	NoneType


"""
Type Conversion
You can convert from one type to
another with the int(), float(), and complex() methods:
"""
x= 5 
c= complex(x) 
print(c)


#random number 

import random 
print(random.randrange(1,10))


# Python is an object-orientated language, and as such 
# it uses classes to define data types, including its primitive types.



#String 
#Multiline Strings
a = """Python is fantasic
Multiline Strings
Multiline Strings"""
print(a)
'''
Strings are Arrays
Like many other popular programming languages, strings in Python are arrays of bytes representing unicode characters.

However, Python does not have a character data type, a single character is simply a string with a length of 1.

Square brackets can be used to access elements of the string.

To get the length of a string, use the len() function.


Check String
To check if a certain phrase or character is present in a string,
we can use the keyword in or not in .
'''

for x in a:
    print(x)

    
txt = "The best things in life are free!"
print("expensive" in txt)

print("expensive" not in txt)

#Slice Strings
# You can return a range of characters by using the slice syntax.
age = 25 
st= "Hello World! " 
print(st[-8:-3])

#upper | lower 
 
print(st.upper())
print(st.lower())


#strip to remove any whitspaces in the string 

print(st.strip())

#replace

print(st.replace("Hello" ,"Hi"))

# The split() 
# method splits the string into substrings
# if it finds instances of the separator:



print(st.split(" "))





# The format() method takes the passed arguments, formats them,
# and places them in the string where the placeholders {} are:
#format

st1  = "Hello , {}"
print(st1.format("Omar"))

quantity = 3
itemno = 567
price = 49.95

myorder = "I want {} pieces of item {} for {} dollars."
print(myorder.format(quantity,itemno, price ))





# isinstance()

# isinstance() function, which can be used to determine
# if an object is of a certain data type:


x = 200
print(isinstance(x, float))

s1 = s3 =  s2= 3 
if s1 == s2 and s2 == s3 :
    print("YES")
# Out:
# (5+0j)
# 8
# Python is fantasic
# Multiline Strings
# Multiline Strings
# P
# y
# t
# h
# o
# n
#
# i
# s
#
# f
# a
# n
# t
# a
# s
# i
# c
#
#
# M
# u
# l
# t
# i
# l
# i
# n
# e
#
# S
# t
# r
# i
# n
# g
# s
#
#
# M
# u
# l
# t
# i
# l
# i
# n
# e
#
# S
# t
# r
# i
# n
# g
# s
# False
# True
#  Worl
# HELLO WORLD!
# hello world!
# Hello World!
# Hi World!
# ['Hello', 'World!', '']
# Hello , Omar
# I want 3 pieces of item 567 for 49.95 dollars.
# False
# YES

# %%
#Python Operators 

# Python divides the operators in the following groups:

# Arithmetic operators => + - * / % ** //
# Assignment operators => = += -= *= /= %= //= **= &= |= ^= >>= <<= 
# Comparison operators => == != > < >= <=  
# Logical operators => and or not 
# Identity operators=> is is not 
# Membership operators=> in not in 
# Bitwise operators=> & | ^ ~ << >>

# %%
# List  oredered   changeable  allow duplicates
# Lists are used to store multiple items in a single variable.
ls = [1 , 2 , 3 ,4 ]
print(ls)
for x in ls :
    print(x)
#len 
print("Length : ", len(ls))
print(type(ls))


#list with constructor
newlist = list(("apple" , "banana", "cherry"))



#negative indexes 
print(newlist[-1])
print(newlist[-3])
print(newlist[-2])
print(newlist[:4])
print(newlist[1:])
newlist[1:3] = ["watermelon"]
print(newlist)


# insert()
# To insert a new list item, without replacing any of the existing values, 
# we can use the insert() method.
# The insert() method inserts an item at the specified index:

newlist.insert(1, "cherry")

newlist.insert(0, "banana")

print(newlist)

#append()
# To add an item to the end of the list, use the append() method:

newlist.append("orange")
print(newlist)


# extend()
# To append elements from another list to the current list, 
# use the extend() method.
# The elements will be added to the end of the list.
# you can add any iterable object (tuples, sets, dictionaries etc.).

tropical = ["mango", "pineapple", "papaya"] 
newlist.extend(tropical)
print(newlist)


thistuple  =("kiwi" , "orange")
newlist.extend(thistuple)

print("extend : " ,  newlist)

#remove() 
#pop() by index
newlist.remove("mango")
newlist.pop()
print(newlist)


#del 
del newlist[0]
print(newlist)

#clear()
#newlist.clear()
print(newlist)
# Out:
# [1, 2, 3, 4]
# 1
# 2
# 3
# 4
# Length :  4
# <class 'list'>
# cherry
# apple
# banana
# ['apple', 'banana', 'cherry']
# ['banana', 'cherry']
# ['apple', 'watermelon']
# ['banana', 'apple', 'cherry', 'watermelon']
# ['banana', 'apple', 'cherry', 'watermelon', 'orange']
# ['banana', 'apple', 'cherry', 'watermelon', 'orange', 'mango', 'pineapple', 'papaya']
# extend :  ['banana', 'apple', 'cherry', 'watermelon', 'orange', 'mango', 'pineapple', 'papaya', 'kiwi', 'orange']
# ['banana', 'apple', 'cherry', 'watermelon', 'orange', 'pineapple', 'papaya', 'kiwi']
# ['apple', 'cherry', 'watermelon', 'orange', 'pineapple', 'papaya', 'kiwi']
# ['apple', 'cherry', 'watermelon', 'orange', 'pineapple', 'papaya', 'kiwi']

# %%
#loop lists 

for x in newlist : 
       print(x)
print("____________________________________________________") 
#using range() len()
for i in range(len(newlist)): 
    print(newlist[i])
print("____________________________________________________")   
#while  len ()
i = 0 
while i < len(newlist) :
    print(newlist[i])
    i = i+ 1 
print("____________________________________________________") 


#Looping Using List Comprehension
[x for x in newlist ]

new = [] 
print("____________________________________________________")
# for i in newlist: 
#     if "a" in i : 
#         new.append(i)
# print(new )


# newlist = [expression for item in iterable if condition == True]
new = [i for i in newlist if "a" in i  ]
print(new )

nn= [i for i in new  ] 
print(nn)


# Iterable
# The iterable can be any iterable object, like a list, tuple, set etc. ex: range()
newlist2  = [i for i in range(10)   if  i < 5] 
print(newlist2)


# You can set the outcome to whatever you like
newfruits  = [x + "S" for x in newlist]
print(newfruits)

# The expression can also contain conditions, not like a filter, but as a way to manipulate the outcome
new_orange = [x if x!= "apple" and x!="watermelon" else "orange" for x in new ]
print(new_orange)


print("_________________________________________")


"""
Sort List Alphanumerically
List objects have a sort() method that will sort the list alphanumerically, ascending, by default:
"""
new[2] = "KWIWI"
new.sort(key = str.lower)
print("new sort  =  "  , new)
list_number  = [100 ,50  , 20 ,82 , 23 ]
list_number.sort()
print(list_number)
# Sort Descending
list_number.sort(reverse = True)
print(list_number)

#key in sort 

def abstract(n):
    return n-65

list_number.sort(key = abstract)
print("listNumer key : "  , list_number)
print("listNumer key : "  , list_number)

#reverse()
new.append("orange")
new.reverse()
print(new)

# Copy a List
# You cannot copy a list simply by typing list2 = list1, because: list2 will only be a reference to list1, and changes made in list1 will automatically also be made in list2.

# There are ways to make a copy, one way is to use the built-in List method copy().
# Another way to make a copy is to use the built-in method list()
newlist_copy = new
print("copy:  =>>>>  " , newlist_copy)
new.append("banana")
print("copy:  =>>>>  " , newlist_copy)

newlist_copy = new.copy()
new.pop()
print("new:"  , new)
print("copy:" , newlist_copy)


#         Join Two Lists 
# There are several ways to join, or
# concatenate, two or more lists in Python.
# One of the easiest ways are by using the + operator.
#append()
#extend()

# Methods 
"""

Method	Description
append()	Adds an element at the end of the list
clear()	Removes all the elements from the list
copy()	Returns a copy of the list
count()	Returns the number of elements with the specified value
extend()	Add the elements of a list (or any iterable), to the end of the current list
index()	Returns the index of the first element with the specified value
insert()	Adds an element at the specified position
pop()	Removes the element at the specified position
remove()	Removes the item with the specified value
reverse()	Reverses the order of the list
sort()	Sorts the list

"""
# Out:
# apple
# cherry
# watermelon
# orange
# pineapple
# papaya
# kiwi
# ____________________________________________________
# apple
# cherry
# watermelon
# orange
# pineapple
# papaya
# kiwi
# ____________________________________________________
# apple
# cherry
# watermelon
# orange
# pineapple
# papaya
# kiwi
# ____________________________________________________
# ____________________________________________________
# ['apple', 'watermelon', 'orange', 'pineapple', 'papaya']
# ['apple', 'watermelon', 'orange', 'pineapple', 'papaya']
# [0, 1, 2, 3, 4]
# ['appleS', 'cherryS', 'watermelonS', 'orangeS', 'pineappleS', 'papayaS', 'kiwiS']
# ['orange', 'orange', 'orange', 'pineapple', 'papaya']
# _________________________________________
# new sort  =   ['apple', 'KWIWI', 'papaya', 'pineapple', 'watermelon']
# [20, 23, 50, 82, 100]
# [100, 82, 50, 23, 20]
# listNumer key :  [20, 23, 50, 82, 100]
# listNumer key :  [20, 23, 50, 82, 100]
# ...

# %%
# ___________________ Tuple_______________________________________________


# Tuple items are ordered, unchangeable, and allow duplicate values.
# The tuple() Constructor => tuple()
thistuple =tuple( ("apple" , "banana" , "cherry" ))
print(thistuple[2])

# # Python - Update Tuples
# Once a tuple is created,
# you cannot change its values. 
# Tuples are unchangeable, or immutable as it also is called.
# But there is a workaround. You can convert the tuple into a list,
# change the list, and convert the list back into a tuple.
#add remove  change 
newthistuple = list(thistuple)

newthistuple[1] = "watermelon"
thistuple = tuple(newthistuple) 
print(thistuple)

# Add tuple to a tuple. You are allowed to add tuples to tuples, so if you want to add one item, (or many), create a new tuple with the item(s), 
# and add it to the existing tuple

new = ("orange" ,)

thistuple += new 
print(thistuple)
# The del keyword can delete the tuple completely
del new 
# Unpacking a Tuple
# When we create a tuple, we normally assign values to it. This is called "packing" a tuple
# But, in Python, we are also allowed to extract the values back into variables. This is called "unpacking":
fruits = ("apple", "banana", "cherry","strawberry", "raspberry")

(green, *yellow, red) = fruits

print(green)
print(yellow)
print(red)

# Join Two Tuples  +   * 
tuple1 = ("a", "b" , "c")
tuple2 = (1, 2, 3)

tuple3 = tuple1 + tuple2
print(tuple3)

fruits = ("apple", "banana", "cherry")
mytuple = fruits * 2

print(mytuple)
# Tuple Methods
# Python has two built-in methods that you can use on tuples.
# count()	Returns the number of times a specified value occurs in a tuple
# index()	Searches the tuple for a specified value and returns the position of where it was found
# Out:
# cherry
# ('apple', 'watermelon', 'cherry')
# ('apple', 'watermelon', 'cherry', 'orange')
# apple
# ['banana', 'cherry', 'strawberry']
# raspberry
# ('a', 'b', 'c', 1, 2, 3)
# ('apple', 'banana', 'cherry', 'apple', 'banana', 'cherry')

# %%
#_______________________________Python Sets______________________________________________#
# A set is a collection which is unordered, unchangeable*, and unindexed. allow no duplicates

thisset={"apple" ,"banana" , "orange" , "apple" , True , 1 , 1 , 2 , False , 0 }
print(thisset)#unorderd
#len
print("lenght:  " , len(thisset))
print("type : " , type(thisset))

newset= set((1 ,2 ,3 ,4 ,5 ,6 ,7 ))
print("new set : " , newset)

#Access Items in Set
for x in thisset: 
    print(x)
#Add Items
# To add one item to a set use the add() method.
thisset.add("cherry")
print(thisset)
#update
# To add items from another set into the current set, use the update() method.
tropical = {"pineapple", "mango", "papaya"}
thisset.update(tropical)
print(thisset)
thisset.update(tuple1)
print(thisset)

#union 

set1 = {"a", "b" , "c"}
set2 = {1, 2, 3}

set3 = set1.union(set2)
print("set3 :  =>>>>>>>>>>/n" , set3)

#remove()   discard()

thisset.remove("c")
print(thisset)
thisset.discard("a")
print(thisset)

# pop() remove random item 
thisset.pop()
print(thisset)

#clear()
print(tropical)
tropical.clear()
print(tropical)
#del 
del tropical



# loop items 
for x in thisset : 
    print(x)

    
# Keep ONLY the Duplicates
# The intersection_update() method will keep only the items that are present in both sets.
# The intersection() method will return a new set, that only contains the items that are present in both sets.
x = {"apple", "banana", "cherry"}
y = {"google", "microsoft", "apple"}

x.intersection_update(y)
z = x.intersection(y)

print(z)
print(x)

# Keep All, But NOT the Duplicates
# The symmetric_difference_update() method will keep only the elements that are NOT present in both sets
# The symmetric_difference() method will return a new set, that contains only the elements that are NOT present in both sets.


x = {"apple", "banana", "cherry"}

y = {"google", "microsoft", "apple"}

x.symmetric_difference_update(y)

print(x)


z = x.symmetric_difference(y)

print(z)


# Set Methods
# add()	Adds an element to the set
# clear()	Removes all the elements from the set
# copy()	Returns a copy of the set
# difference()	Returns a set containing the difference between two or more sets
# difference_update()	Removes the items in this set that are also included in another, specified set
# discard()	Remove the specified item
# intersection()	Returns a set, that is the intersection of two other sets
# intersection_update()	Removes the items in this set that are not present in other, specified set(s)
# isdisjoint()	Returns whether two sets have a intersection or not
# issubset()	Returns whether another set contains this set or not
# issuperset()	Returns whether this set contains another set or not
# pop()	Removes an element from the set
# remove()	Removes the specified element
# symmetric_difference()	Returns a set with the symmetric differences of two sets
# symmetric_difference_update()	inserts the symmetric differences from this set and another
# union()	Return a set containing the union of sets
# update()
# Out:
# {False, 'orange', 2, True, 'banana', 'apple'}
# lenght:   6
# type :  <class 'set'>
# new set :  {1, 2, 3, 4, 5, 6, 7}
# False
# orange
# 2
# True
# banana
# apple
# {False, 'orange', 2, True, 'banana', 'cherry', 'apple'}
# {False, 'orange', 2, True, 'cherry', 'banana', 'mango', 'pineapple', 'papaya', 'apple'}
# {False, 'orange', 2, True, 'c', 'b', 'cherry', 'a', 'banana', 'mango', 'pineapple', 'papaya', 'apple'}
# set3 :  =>>>>>>>>>>/n {'c', 1, 'a', 2, 3, 'b'}
# {False, 'orange', 2, True, 'b', 'cherry', 'a', 'banana', 'mango', 'pineapple', 'papaya', 'apple'}
# {False, 'orange', 2, True, 'b', 'cherry', 'banana', 'mango', 'pineapple', 'papaya', 'apple'}
# {'orange', 2, True, 'b', 'cherry', 'banana', 'mango', 'pineapple', 'papaya', 'apple'}
# {'papaya', 'mango', 'pineapple'}
# set()
# orange
# 2
# True
# b
# cherry
# banana
# mango
# pineapple
# papaya
# apple
# {'apple'}
# {'apple'}
# {'microsoft', 'cherry', 'banana', 'google'}
# {'cherry', 'banana', 'apple'}

# %%
#__________________________________Dictionary_________________________________#
# Dictionaries are used to store data values in key:value pairs.
# A dictionary is a collection which is ordered*, changeable and do not allow duplicates.
# Dictionary items are ordered, changeable, and does not allow duplicates.

thisdict = {
    "brand" :"ford", 
    "model": "Mustang", 
    "Year": 1964, 
    "Year": 2022,
    "colors": ["red", "white", "blue"], 
}
print(thisdict["Year"])


print(thisdict)

#len
print(len(thisdict))
print("\n type : " , type(thisdict)  , "\n")

newdict = dict( name=" john" , age  = 36  , country = "Norway")
print(newdict)

#Access items of dict 


d = newdict["name"]
print(d)
#get()
d= newdict.get("age")
print(d)
#Get Keys
#keys()
print(thisdict.keys())

# values()
print(thisdict.values())

# The items() method will return each item in a dictionary, as tuples in a list.

print(thisdict.items())


# Check if Key Exists


if "model" in thisdict: 
    print("Yes , model is one of the keys in the dict ")

    
#change values
thisdict["brand"] = "BMW"     
print("\n" , thisdict)

thisdict.update({"Year" :  2023 , "age" : 50 })
print(thisdict)


#remove Items using pop()
# The popitem() method removes the last inserted item
# The del keyword removes the item with the specified key name
thisdict.pop("age")
print(thisdict)


#del
del thisdict["colors"]
print(thisdict)

print(newdict)
del newdict


# clear()

thisdict.clear()
print(thisdict)

#for in dict 
thisdict = {
    "brand" :"ford", 
    "model": "Mustang", 
    "Year": 1964, 
    "Year": 2022,
    "colors": ["red", "white", "blue"], 
}
for x, y  in thisdict.items(): 
    print(x , y )
    
for x in thisdict: 
    print(thisdict[x])
    
    
# copy()   dict() copy the dict

mynewdict = thisdict.copy()
mynewdict1 = dict(thisdict)

print("\n my new dict "  , mynewdict)
print("\n my new dict1 "  , thisdict)


# Nested Dictionaries
# A dictionary can contain dictionaries, this is called nested dictionaries


myfamily = {
  "child1" : {
    "name" : "Emil",
    "year" : 2004
  },
  "child2" : {
    "name" : "Tobias",
    "year" : 2007
  },
  "child3" : {
    "name" : "Linus",
    "year" : 2011
  }
}

print(myfamily["child1"]["name"])


# Dictionary Methods

# clear()	Removes all the elements from the dictionary
# copy()	Returns a copy of the dictionary
# fromkeys()	Returns a dictionary with the specified keys and value
# get()	Returns the value of the specified key
# items()	Returns a list containing a tuple for each key value pair
# keys()	Returns a list containing the dictionary's keys
# pop()	Removes the element with the specified key
# popitem()	Removes the last inserted key-value pair
# setdefault()	Returns the value of the specified key. If the key does not exist: insert the key, with the specified value
# update()	Updates the dictionary with the specified key-value pairs
# values()	Returns a list of all the values in the dictionary
# Out:
# 2022
# {'brand': 'ford', 'model': 'Mustang', 'Year': 2022, 'colors': ['red', 'white', 'blue']}
# 4
#
#  type :  <class 'dict'>
#
# {'name': ' john', 'age': 36, 'country': 'Norway'}
#  john
# 36
# dict_keys(['brand', 'model', 'Year', 'colors'])
# dict_values(['ford', 'Mustang', 2022, ['red', 'white', 'blue']])
# dict_items([('brand', 'ford'), ('model', 'Mustang'), ('Year', 2022), ('colors', ['red', 'white', 'blue'])])
# Yes , model is one of the keys in the dict
#
#  {'brand': 'BMW', 'model': 'Mustang', 'Year': 2022, 'colors': ['red', 'white', 'blue']}
# {'brand': 'BMW', 'model': 'Mustang', 'Year': 2023, 'colors': ['red', 'white', 'blue'], 'age': 50}
# {'brand': 'BMW', 'model': 'Mustang', 'Year': 2023, 'colors': ['red', 'white', 'blue']}
# {'brand': 'BMW', 'model': 'Mustang', 'Year': 2023}
# {'name': ' john', 'age': 36, 'country': 'Norway'}
# {}
# brand ford
# model Mustang
# Year 2022
# colors ['red', 'white', 'blue']
# ford
# Mustang
# 2022
# ['red', 'white', 'blue']
#
# ...

# %%
#  Ternary Operators    |     Conditional Expressions.    

a= 330  
b =5
print("A") if a> b else print("=") if a== b else print("B")


if b > a  : 
    pass

print("Five is greater than two!") if a > b else print("=")
# Out:
# A
# Five is greater than two!

# %%
import math
import os
import random
import re
import sys



if __name__ == '__main__':
    n = int(input().strip())
    if n %2 == 0 : 
        if n >= 6  and n <= 20 : 
            print("Weird")
        else:  
            print("Not Weird")
    else:
        print("Weird")
# Out:
# 100
# Not Weird

# %%
# Python Loops  # for   # while
i= 1 
while i < 10 : 
   
#     if i == 5 : 
#         break
    if i == 9 : 
        continue
    print(i)   
    i+=1   
# else in while loop
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8

# %%
import sys

if __name__ == '__main__':
    n = int(input())
    
    for i in range(n):
        sys.stdout.write(str(i+1))

# %%
# Functions 

# From a function's perspective:

# A parameter is the variable listed inside the parentheses in the function definition.

# An argument is the value that is sent to the function when it is called

# Arbitrary Arguments, *args
# If you do not know how many arguments that will be passed into your function, add a * before the parameter name in the function definition.
# Keyword Arguments
# Arbitrary Keyword Arguments, **kwargs
def my_func(fname): # parameter
    print(fname)
my_func("omar")#argument 

def kids(*kids):
    print(kids[2])

# default parameter value 
def my_function(country = "Norway"):
      print("I am from " + country)

my_function("Sweden")
my_function("India")
my_function()
my_function("Brazil")



def my_func(f):
    for x in f : 
        print(x)
fruits = ["apple" ,"orange" , "cherry"]       
my_func(fruits)  



def tri_recursion(k):
        if(k > 0):
            result = k + tri_recursion(k - 1)
            print(result)
        else:
            result = 0
        return result

print("\n\nRecursion Example Results")
tri_recursion(6)



# 6 +15   21 
# 5 + 10  15
# 4 + 6   10
# 3 + 3   6
# 2 + 1   3  
# 1 + 0   1
# Out:
# omar
# I am from Sweden
# I am from India
# I am from Norway
# I am from Brazil
# apple
# orange
# cherry
#
#
# Recursion Example Results
# 1
# 3
# 6
# 10
# 15
# 21
# 21

# %%
# lambda function 
# A lambda function is a small anonymous function.
# lambda arguments : expression
# 
# A lambda function can take any number of arguments, but can only have one expression.


x = lambda a : a+ 5 
print(x(5))


x = lambda a, b, c : a + b + c
print(x(5, 6, 2))

# Why Use Lambda Functions?
# The power of lambda is better shown when you use them as an anonymous function inside another function.


# Say you have a function definition that takes one argument, and that argument will be multiplied with an unknown number:
def myfunc(n):
      return lambda a : a * n

mydoubler = myfunc(2)

print(mydoubler(11))

# Use lambda functions when an anonymous function is required for a short period of time.
# Out:
# 10
# 13
# 22
